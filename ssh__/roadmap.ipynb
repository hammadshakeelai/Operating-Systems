# %% [markdown]
# [over the wire _ wargame -> bandit](https://overthewire.org/wargames/bandit/)

# %%
ssh user@machine

# %%
sudo systemctl status ssh

# %%
ssh bandit.labs.overthewire.org -p 2220 -l bandit0

# %% [markdown]
# password is bandit0
